# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('car_price.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                car_name car_prices_in_rupee  \
# 0           0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1           1            Renault Duster RXZ Turbo CVT          12.83 Lakh
# 2           2                      Toyota Camry 2.5 G          16.40 Lakh
# 3           3                       Honda Jazz VX CVT           7.77 Lakh
# 4           4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh
#
#    kms_driven fuel_type transmission  ownership  manufacture   engine    Seats
# 0  86,226 kms    Diesel       Manual  1st Owner         2017  1956 cc  5 Seats
# 1  13,248 kms    Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats
# 2  60,343 kms    Petrol    Automatic  1st Owner         2016  2494 cc  5 Seats
# 3  26,696 kms    Petrol    Automatic  1st Owner         2018  1199 cc  5 Seats
# 4  69,414 kms    Petrol       Manual  1st Owner         2016  1199 cc  5 Seats

# %%
df.shape
# Out:
# (5512, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           5512 non-null   int64
#  1   car_name             5512 non-null   object
#  2   car_prices_in_rupee  5512 non-null   object
#  3   kms_driven           5512 non-null   object
#  4   fuel_type            5512 non-null   object
#  5   transmission         5512 non-null   object
#  6   ownership            5512 non-null   object
#  7   manufacture          5512 non-null   int64
#  8   engine               5512 non-null   object
#  9   Seats                5512 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 430.8+ KB

# %%
len(df[df.duplicated()])
# Out:
# 0

# %%
df['car_prices_in_rupee'].str.split(' ').head()
# Out:
# 0    [10.03, Lakh]
# 1    [12.83, Lakh]
# 2    [16.40, Lakh]
# 3     [7.77, Lakh]
# 4     [5.15, Lakh]
# Name: car_prices_in_rupee, dtype: object

# %%
df['car_prices_in_rupee'].str.split(' ').str.get(0)
# Out:
# 0       10.03
# 1       12.83
# 2       16.40
# 3        7.77
# 4        5.15
#         ...
# 5507    28.90
# 5508    64.90
# 5509    13.75
# 5510    29.90
# 5511    31.90
# Name: car_prices_in_rupee, Length: 5512, dtype: object

# %%
df['car_prices_in_rupee']=df['car_prices_in_rupee'].str.split(' ').str.get(0)

# %%
df['car_prices_in_rupee']=df['car_prices_in_rupee'].str.replace(',','').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           5512 non-null   int64
#  1   car_name             5512 non-null   object
#  2   car_prices_in_rupee  5512 non-null   float64
#  3   kms_driven           5512 non-null   object
#  4   fuel_type            5512 non-null   object
#  5   transmission         5512 non-null   object
#  6   ownership            5512 non-null   object
#  7   manufacture          5512 non-null   int64
#  8   engine               5512 non-null   object
#  9   Seats                5512 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 430.8+ KB

# %%
df['kms_driven'].str.split(' ').str.get(0)
# Out:
# 0       86,226
# 1       13,248
# 2       60,343
# 3       26,696
# 4       69,414
#          ...
# 5507    45,000
# 5508    29,000
# 5509    90,000
# 5510    79,000
# 5511    42,000
# Name: kms_driven, Length: 5512, dtype: object

# %%
df['kms_driven']=df['kms_driven'].str.split(' ').str.get(0)

# %%
df['kms_driven']=df['kms_driven'].str.replace(',','').astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           5512 non-null   int64
#  1   car_name             5512 non-null   object
#  2   car_prices_in_rupee  5512 non-null   float64
#  3   kms_driven           5512 non-null   int32
#  4   fuel_type            5512 non-null   object
#  5   transmission         5512 non-null   object
#  6   ownership            5512 non-null   object
#  7   manufacture          5512 non-null   int64
#  8   engine               5512 non-null   object
#  9   Seats                5512 non-null   object
# dtypes: float64(1), int32(1), int64(2), object(6)
# memory usage: 409.2+ KB

# %%
df['engine'].str.split(' ').head()
# Out:
# 0    [1956, cc]
# 1    [1330, cc]
# 2    [2494, cc]
# 3    [1199, cc]
# 4    [1199, cc]
# Name: engine, dtype: object

# %%
df['engine'].str.split(' ').str.get(0)
# Out:
# 0       1956
# 1       1330
# 2       2494
# 3       1199
# 4       1199
#         ...
# 5507    2995
# 5508    1968
# 5509    2755
# 5510    2967
# 5511    1991
# Name: engine, Length: 5512, dtype: object

# %%
df['engine'].str.split(' ').str.get(0).astype(float)
# Out:
# 0       1956.0
# 1       1330.0
# 2       2494.0
# 3       1199.0
# 4       1199.0
#          ...
# 5507    2995.0
# 5508    1968.0
# 5509    2755.0
# 5510    2967.0
# 5511    1991.0
# Name: engine, Length: 5512, dtype: float64

# %%
df['engine']=df['engine'].str.split(' ').str.get(0).astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           5512 non-null   int64
#  1   car_name             5512 non-null   object
#  2   car_prices_in_rupee  5512 non-null   float64
#  3   kms_driven           5512 non-null   int32
#  4   fuel_type            5512 non-null   object
#  5   transmission         5512 non-null   object
#  6   ownership            5512 non-null   object
#  7   manufacture          5512 non-null   int64
#  8   engine               5512 non-null   float64
#  9   Seats                5512 non-null   object
# dtypes: float64(2), int32(1), int64(2), object(5)
# memory usage: 409.2+ KB

# %%
df['ownership'].str.split(' ').str.get(0)
# Out:
# 0       1st
# 1       1st
# 2       1st
# 3       1st
# 4       1st
#        ...
# 5507    1st
# 5508    2nd
# 5509    2nd
# 5510    3rd
# 5511    2nd
# Name: ownership, Length: 5512, dtype: object

# %%
df['ownership']=df['ownership'].str.split(' ').str.get(0)

# %%
df['ownership']=df['ownership'].str.replace('st','')
df['ownership']=df['ownership'].str.replace('nd','')
df['ownership']=df['ownership'].str.replace('rd','')
df['ownership']=df['ownership'].str.replace('th','')

# %%
df['ownership'].str.split(' ').str.get(0).astype(float)
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 5507    1.0
# 5508    2.0
# 5509    2.0
# 5510    3.0
# 5511    2.0
# Name: ownership, Length: 5512, dtype: float64

# %%
df['ownership']=df['ownership'].str.split(' ').str.get(0).astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           5512 non-null   int64
#  1   car_name             5512 non-null   object
#  2   car_prices_in_rupee  5512 non-null   float64
#  3   kms_driven           5512 non-null   int32
#  4   fuel_type            5512 non-null   object
#  5   transmission         5512 non-null   object
#  6   ownership            5512 non-null   float64
#  7   manufacture          5512 non-null   int64
#  8   engine               5512 non-null   float64
#  9   Seats                5512 non-null   object
# dtypes: float64(3), int32(1), int64(2), object(4)
# memory usage: 409.2+ KB

# %%
df['Seats'].str.split(' ').str.get(0).astype(int).head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# Name: Seats, dtype: int32

# %%
df['Seats']=df['Seats'].str.split(' ').str.get(0).astype(int).head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           5512 non-null   int64
#  1   car_name             5512 non-null   object
#  2   car_prices_in_rupee  5512 non-null   float64
#  3   kms_driven           5512 non-null   int32
#  4   fuel_type            5512 non-null   object
#  5   transmission         5512 non-null   object
#  6   ownership            5512 non-null   float64
#  7   manufacture          5512 non-null   int64
#  8   engine               5512 non-null   float64
#  9   Seats                5 non-null      float64
# dtypes: float64(4), int32(1), int64(2), object(3)
# memory usage: 409.2+ KB

# %%
L=['1','2','three',4,5.6]

# %%
L1=L[0:3]
L1
# Out:
# ['1', '2', 'three']

# %%
len(L1)
# Out:
# 3
