# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("USA_Sales_Data.csv",encoding='latin1')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            5825
# Quantity           14
# Discount           12
# Profit           7287
# dtype: int64

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df['Order ID'].value_counts()
# Out:
# Order ID
# CA-2017-100111    14
# CA-2017-157987    12
# CA-2016-165330    11
# US-2016-108504    11
# US-2015-126977    10
#                   ..
# CA-2014-110422     1
# CA-2016-125794     1
# CA-2017-163566     1
# US-2015-151435     1
# CA-2016-130225     1
# Name: count, Length: 5009, dtype: int64

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])

# %%
df['Ship Date']=pd.to_datetime(df['Ship Date'])

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
len(df[df.duplicated()])
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# Row ID           0.0
# Order ID         0.0
# Order Date       0.0
# Ship Date        0.0
# Ship Mode        0.0
# Customer ID      0.0
# Customer Name    0.0
# Segment          0.0
# Country          0.0
# City             0.0
# State            0.0
# Postal Code      0.0
# Region           0.0
# Product ID       0.0
# Category         0.0
# Sub-Category     0.0
# Product Name     0.0
# Sales            0.0
# Quantity         0.0
# Discount         0.0
# Profit           0.0
# dtype: float64

# %%
df.drop(['Row ID'],axis=1,inplace= True)

# %%
df.dtypes
# Out:
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df['Category'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.show()

# %%
df['Sub-Category'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Region'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Segment'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(8,8))
sns.boxplot(data=df,x='Customer ID')
plt.show()

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
plt.figure(figsize=(10,2))
sns.histplot(data=df,x='Sub-Category')
plt.show()

# %%
plt.figure(figsize=(10,2))
sns.histplot(data=df,x='Sub-Category',kde=True,hue='Category')
plt.show()

# %%
plt.figure(figsize=(10,2))
sns.countplot(data=df,x='Sub-Category',hue='Category')
plt.show()

# %%
plt.figure(figsize=(10,2))
sns.histplot(data=df,x='Profit')
plt.show()

# %%
plt.figure(figsize=(10,2))
sns.boxplot(data=df,x='Category',y='Discount')
plt.show()

# %%
plt.figure(figsize=(10,2))
sns.boxplot(data=df,x='Category',y='Quantity')
plt.show()

# %%
plt.figure(figsize=(10,2))
sns.scatterplot(data=df,x='Profit',y='Quantity')
plt.show()

# %%
plt.figure(figsize=(10,2))
sns.lineplot(data=df,x='Profit',y='Quantity')
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(10,5))
df['Category'].value_counts().plot.bar()
plt.show()

# %%
plt.figure(figsize=(10,5))
df['Sub-Category'].value_counts().plot.bar()
plt.show()

# %%
df.corr(numeric_only= True )
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(numeric_only=True),annot=True,linewidths=1)
plt.title('correlation bitween numeric columns')
plt.show()

# %%
plt.figure(figsize=(25,8))
sns.countplot(data=df,x="Category",hue="Discount")
plt.show()

# %%
dfc=df.copy()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
dfc.loc[:,['Sales']]=sc.fit_transform(dfc.loc[:,['Sales']])

# %%
dfc.loc[:,['Sales']]
# Out:
#          Sales
# 0     0.051510
# 1     0.805633
# 2    -0.345368
# 3     1.167688
# 4    -0.332935
# ...        ...
# 9989 -0.328314
# 9990 -0.221269
# 9991  0.046080
# 9992 -0.321331
# 9993  0.021344
#
# [9994 rows x 1 columns]

# %%
dfc[['Sales']]
# Out:
#          Sales
# 0     0.051510
# 1     0.805633
# 2    -0.345368
# 3     1.167688
# 4    -0.332935
# ...        ...
# 9989 -0.328314
# 9990 -0.221269
# 9991  0.046080
# 9992 -0.321331
# 9993  0.021344
#
# [9994 rows x 1 columns]

# %%
df.groupby('Sub-Category')['Sales'].sum()
# Out:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27118.7920
# Binders        203412.7330
# Bookcases      114879.9963
# Chairs         328449.1030
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91705.1640
# Labels          12486.3120
# Machines       189238.6310
# Paper           78479.2060
# Phones         330007.0540
# Storage        223843.6080
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64

# %%
top_10_sales=df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False).head(10)

# %%
top_10_sales
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         328449.1030
# Storage        223843.6080
# Tables         206965.5320
# Binders        203412.7330
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10,12))
top_10_sales.plot.bar()
plt.show()

# %%
top_10_sales=df.groupby('Sub-Category')['Sales'].min().sort_values(ascending=False).head(10)
top_10_sales
# Out:
# Sub-Category
# Copiers        299.990
# Bookcases       35.490
# Chairs          26.640
# Tables          24.368
# Machines        11.560
# Storage          4.464
# Paper            3.380
# Phones           2.970
# Labels           2.088
# Furnishings      1.892
# Name: Sales, dtype: float64

# %%
top_10_sales=df.groupby('Sub-Category')['Sales'].max().sort_values(ascending=False).head(10)
top_10_sales
# Out:
# Sub-Category
# Machines       22638.480
# Copiers        17499.950
# Binders         9892.740
# Supplies        8187.650
# Phones          4548.810
# Chairs          4416.174
# Bookcases       4404.900
# Tables          4297.644
# Accessories     3347.370
# Storage         2934.330
# Name: Sales, dtype: float64

# %%
top_10_sales=df.groupby('Sub-Category')['Sales'].mean().sort_values(ascending=False).head(10)
top_10_sales
# Out:
# Sub-Category
# Copiers        2198.941618
# Machines       1645.553313
# Tables          648.794771
# Chairs          532.332420
# Bookcases       503.859633
# Phones          371.211534
# Storage         264.590553
# Supplies        245.650200
# Appliances      230.755710
# Accessories     215.974604
# Name: Sales, dtype: float64

# %%
top_10_sales=df.groupby('Sub-Category')['Sales'].median().sort_values(ascending=False).head(10)
top_10_sales
# Out:
# Sub-Category
# Copiers        1099.98000
# Machines        599.98500
# Tables          447.84000
# Chairs          362.13600
# Bookcases       306.82025
# Phones          209.97000
# Storage         113.92800
# Accessories     100.00000
# Appliances       82.69000
# Furnishings      41.96000
# Name: Sales, dtype: float64

# %%
df.groupby('Sub-Category')['Profit'].sum()
# Out:
# Sub-Category
# Accessories    41936.6357
# Appliances     18138.0054
# Art             6527.7870
# Binders        30221.7633
# Bookcases      -3472.5560
# Chairs         26590.1663
# Copiers        55617.8249
# Envelopes       6964.1767
# Fasteners        949.5182
# Furnishings    13059.1436
# Labels          5546.2540
# Machines        3384.7569
# Paper          34053.5693
# Phones         44515.7306
# Storage        21278.8264
# Supplies       -1189.0995
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
top_10_profit=df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False).head(10)
top_10_profit
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Chairs         26590.1663
# Storage        21278.8264
# Appliances     18138.0054
# Furnishings    13059.1436
# Envelopes       6964.1767
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10,8))
top_10_profit.plot.bar()
plt.show()

# %%
top_10_profit.plot.pie(autopct='%1.1f%%')
plt.show()

# %%
df['Category'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
plt.figure(figsize=(10,6))
df['Category'].value_counts().plot.bar()
plt.show()

# %%
df1=df.copy()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
df1.loc[:,['Sales']]=sc.fit_transform(df1.loc[:,['Sales']])

# %%
df1.loc[:,['Sales']]
# Out:
#          Sales
# 0     0.051510
# 1     0.805633
# 2    -0.345368
# 3     1.167688
# 4    -0.332935
# ...        ...
# 9989 -0.328314
# 9990 -0.221269
# 9991  0.046080
# 9992 -0.321331
# 9993  0.021344
#
# [9994 rows x 1 columns]

# %%
df1['Sales']
# Out:
# 0       0.051510
# 1       0.805633
# 2      -0.345368
# 3       1.167688
# 4      -0.332935
#           ...
# 9989   -0.328314
# 9990   -0.221269
# 9991    0.046080
# 9992   -0.321331
# 9993    0.021344
# Name: Sales, Length: 9994, dtype: float64

# %%
df.groupby('Sub-Category')['Profit'].sum()
# Out:
# Sub-Category
# Accessories    41936.6357
# Appliances     18138.0054
# Art             6527.7870
# Binders        30221.7633
# Bookcases      -3472.5560
# Chairs         26590.1663
# Copiers        55617.8249
# Envelopes       6964.1767
# Fasteners        949.5182
# Furnishings    13059.1436
# Labels          5546.2540
# Machines        3384.7569
# Paper          34053.5693
# Phones         44515.7306
# Storage        21278.8264
# Supplies       -1189.0995
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
top_10_profit=df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False).head(10)

# %%
top_10_profit
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Chairs         26590.1663
# Storage        21278.8264
# Appliances     18138.0054
# Furnishings    13059.1436
# Envelopes       6964.1767
# Name: Profit, dtype: float64

# %%
top_10_profit.plot.pie(autopct='%1.1F%%')
plt.show()

# %%
top_10_profit.plot.bar()
plt.show()

# %%
df2=df.copy()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
df2.loc[:,['Profit']]=sc.fit_transform(df2.loc[:,['Profit']])

# %%
df2.loc[:,['Profit']]
# Out:
#         Profit
# 0     0.056593
# 1     0.815054
# 2    -0.093002
# 3    -1.757484
# 4    -0.111593
# ...        ...
# 9989 -0.104821
# 9990 -0.055598
# 9991 -0.039546
# 9992 -0.065473
# 9993  0.189078
#
# [9994 rows x 1 columns]

# %%
df2['Profit']
# Out:
# 0       0.056593
# 1       0.815054
# 2      -0.093002
# 3      -1.757484
# 4      -0.111593
#           ...
# 9989   -0.104821
# 9990   -0.055598
# 9991   -0.039546
# 9992   -0.065473
# 9993    0.189078
# Name: Profit, Length: 9994, dtype: float64

# %%
plt.figure(figsize=(10,2))
sns.boxplot(data=df,x='Quantity')
plt.show()

# %%
q1=df['Quantity'].quantile(0.25)
q3=df['Quantity'].quantile(0.75)
iqr=q3-q1
upper_bound=q3+1.5*iqr
lower_bound=q1-1.5*iqr
df['Quantity']=np.where(df['Quantity']>upper_bound,upper_bound,df['Quantity'])
df['Quantity']=np.where(df['Quantity']<upper_bound,upper_bound,df['Quantity'])

# %%
plt.figure(figsize=(10,2))
sns.boxplot(data=df,x='Quantity',color='green')
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.009671 -0.001359 -0.004016  0.013480  0.012497
# Postal Code  0.009671     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales       -0.001359    -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity    -0.004016     0.012761  0.200795  1.000000  0.008623  0.066253
# Discount     0.013480     0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit       0.012497    -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(numeric_only=True),annot=True,linewidths=1)
plt.title('correlation bitween numeric columns')
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.009671 -0.001359 -0.004016  0.013480  0.012497
# Postal Code  0.009671     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales       -0.001359    -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity    -0.004016     0.012761  0.200795  1.000000  0.008623  0.066253
# Discount     0.013480     0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit       0.012497    -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(numeric_only=True),annot=True,linewidth=0.5)
plt.title('correlation')
plt.show()

# %%
df.groupby('City')['Profit'].sum()
# Out:
# City
# Aberdeen          6.6300
# Abilene          -3.7584
# Akron          -186.6356
# Albuquerque     634.0881
# Alexandria      318.6183
#                  ...
# Woonsocket       78.6791
# Yonkers        2767.7557
# York           -102.1692
# Yucaipa          13.2080
# Yuma           -465.9909
# Name: Profit, Length: 531, dtype: float64

# %%
top_10_Region=df.groupby('City')['Profit'].sum().sort_values(ascending=False).head(10)

# %%
top_10_Region
# Out:
# City
# New York City    62036.9837
# Los Angeles      30440.7579
# Seattle          29156.0967
# San Francisco    17507.3854
# Detroit          13181.7908
# Lafayette        10018.3876
# Jackson           7581.6828
# Atlanta           6993.6629
# Minneapolis       6824.5846
# San Diego         6377.1960
# Name: Profit, dtype: float64

# %%
top_10_Region.plot.pie(autopct='%1.1f%%')
plt.show()

# %%
top_10_Region.plot.bar()
plt.show()

# %%
sns.boxplot(data=df,x='Quantity')
plt.show()

# %%
q1=df['Quantity'].quantile(0.25)
q3=df['Quantity'].quantile(0.75)
iqr=q3-q1
upper_bound=q3+1.5*iqr
df['Quantity']=np.where(df['Quantity']>upper_bound,upper_bound,df['Quantity'])

# %%
sns.boxplot(data=df,x='Quantity')
plt.show()

# %%
df1=df.copy()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
df1.loc[:,['Profit']]=sc.fit_transform(df1.loc[:,['Profit']])

# %%
df1.loc[:,['Profit']]
# Out:
#         Profit
# 0     0.056593
# 1     0.815054
# 2    -0.093002
# 3    -1.757484
# 4    -0.111593
# ...        ...
# 9989 -0.104821
# 9990 -0.055598
# 9991 -0.039546
# 9992 -0.065473
# 9993  0.189078
#
# [9994 rows x 1 columns]

# %%
df1['Profit']
# Out:
# 0       0.056593
# 1       0.815054
# 2      -0.093002
# 3      -1.757484
# 4      -0.111593
#           ...
# 9989   -0.104821
# 9990   -0.055598
# 9991   -0.039546
# 9992   -0.065473
# 9993    0.189078
# Name: Profit, Length: 9994, dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.009671 -0.001359 -0.004431  0.013480  0.012497
# Postal Code  0.009671     1.000000 -0.023854  0.013351  0.058443 -0.029961
# Sales       -0.001359    -0.023854  1.000000  0.200133 -0.028190  0.479064
# Quantity    -0.004431     0.013351  0.200133  1.000000  0.010275  0.063099
# Discount     0.013480     0.058443 -0.028190  0.010275  1.000000 -0.219487
# Profit       0.012497    -0.029961  0.479064  0.063099 -0.219487  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,linewidth=0.5)
plt.title('corr')
plt.show()

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date                object
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                float64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df['Ship Date']=pd.to_datetime(df['Ship Date'])

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                float64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df.groupby('Sub-Category')['Discount'].sum()
# Out:
# Sub-Category
# Accessories     60.80
# Appliances      77.60
# Art             59.60
# Binders        567.00
# Bookcases       48.14
# Chairs         105.00
# Copiers         11.00
# Envelopes       20.40
# Fasteners       17.80
# Furnishings    132.40
# Labels          25.00
# Machines        35.20
# Paper          102.60
# Phones         137.40
# Storage         63.20
# Supplies        14.60
# Tables          83.35
# Name: Discount, dtype: float64

# %%
top_10_dis=df.groupby('Sub-Category')['Discount'].sum().sort_values(ascending=False).head(10)
top_10_dis
# Out:
# Sub-Category
# Binders        567.00
# Phones         137.40
# Furnishings    132.40
# Chairs         105.00
# Paper          102.60
# Tables          83.35
# Appliances      77.60
# Storage         63.20
# Accessories     60.80
# Art             59.60
# Name: Discount, dtype: float64

# %%
top_10_dis.plot.bar()
plt.show()

# %%
top_10_dis.plot.pie(autopct='%1.1f%%')
plt.show()

# %%
df.corr(numeric_only=True)

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,linewidth=0.5)
plt.show()
